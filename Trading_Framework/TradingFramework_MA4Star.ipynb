# %%
from trading_framework import TradingFramework
# from MAStrategy import MAStrategy
from MA4Star import MA4Star
# Out:
# 2025-10-10 23:55:03.426254: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-10-10 23:55:03.521966: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-10-10 23:55:03.546345: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-10-10 23:55:03.713737: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# Initialize framework
ticker="TSLA"
# framework = TradingFramework(ticker=ticker, strategy=MAStrategy(ticker=ticker))
framework = TradingFramework(ticker=ticker, strategy=MA4Star(ticker=ticker))

# %%
# Fetch data
framework.fetch_data()

# %%
preprocessed_data = framework.preprocess_data()

# %%
# Train deep learning models
framework.train_dl_models()

# %%
# Run backtest
framework.run_backtest()

# %%
bt_result = framework.validation_backtest.get_results()

# %%
display(bt_result)

# %%
# Display resdisplayults
framework.display_results(height=800, width=1100)

# %%
# framework.display_results(output_format='plotly')
# framework.display_results(output_format='pdf', output_file=f'{ticker}_backtest_report.pdf')

# %%
framework.validation_backtest.get_results().to_csv(f"{ticker}_validation_result.csv")
