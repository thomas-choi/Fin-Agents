# %%
from trading_framework import TradingFramework
# from MAStrategy import MAStrategy
from MA4Star import MA4Star
# Out:
# 2025-10-11 00:33:43.219045: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-10-11 00:33:43.232194: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-10-11 00:33:43.235968: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-10-11 00:33:43.247343: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# Initialize framework
ticker="TSLA"
# framework = TradingFramework(ticker=ticker, strategy=MAStrategy(ticker=ticker))
framework = TradingFramework(ticker=ticker, strategy=MA4Star(ticker=ticker))
# Out:
# INFO:root:Initialized MA4Star with ticker: TSLA
# DEBUG:root: init ./exports/data

# %%
# Fetch data
framework.fetch_data()
# Out:
# DEBUG:root:Fetching data for TSLA from 2020-01-01 to 2025-07-15
# DEBUG:root: init ./exports/data for fetch_data
# DEBUG:root:Checking cache file ./exports/data/TSLA_2020-01-01_2025-07-15.csv
# INFO:root:Loading cached data for TSLA from ./exports/data/TSLA_2020-01-01_2025-07-15.csv

# %%
preprocessed_data = framework.preprocess_data()
# Out:
# DEBUG:root:Find rising star: lookback=100 at 2020-07-27 00:00:00 with 100.87133026123048, 94.46666717529295, 102.63999938964844
# DEBUG:root:Rising Star found at 2020-07-27 00:00:00 with Low=94.1999969482422
# DEBUG:root:Find rising star: lookback=100 at 2020-11-11 00:00:00 with 140.4199981689453, 136.7866668701172, 139.0433349609375
# DEBUG:root:Rising Star found at 2020-11-11 00:00:00 with Low=136.86000061035156
# DEBUG:root:Find rising star: lookback=100 at 2021-02-24 00:00:00 with 238.1666717529297, 232.94667053222656, 247.33999633789065
# DEBUG:root:Rising Star found at 2021-02-24 00:00:00 with Low=231.38999938964844
# DEBUG:root:Find Evening star: lookback=100 at 2021-03-03 00:00:00 with 239.47666931152344, 228.81333923339844, 217.73333740234372
# DEBUG:root:Evening Star found at 2021-03-03 00:00:00 with High=233.5666656494141
# DEBUG:root:Find rising star: lookback=100 at 2021-08-18 00:00:00 with 228.72332763671875, 221.90333557128903, 229.663330078125
# ...
